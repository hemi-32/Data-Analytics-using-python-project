# %% [markdown]
# <a href="https://colab.research.google.com/github/hemi-32/Data-Analytics-using-python-project/blob/main/Day2_internship_Simple_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("Welcome",name)
greet("hemila")
# Out:
# Welcome hemila

# %%
def greet():
  print("HI")
greet()
# Out:
# HI

# %%
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30
