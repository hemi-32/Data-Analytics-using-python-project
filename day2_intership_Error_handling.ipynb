# %% [markdown]
# <a href="https://colab.research.google.com/github/hemi-32/Data-Analytics-using-python-project/blob/main/day2_intership_Error_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num=int(input("Enter Number:"))
  print(num)
except:
  print("invalid input")
# Out:
# Enter Number:132
# 132
